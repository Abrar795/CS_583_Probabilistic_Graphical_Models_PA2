# %% [markdown]
# # Parameter Estimation
#
# ### a. [22.5 pts] Perform parameter estimation using the Maximum Likelihood algorithm. Print out CPDs and local independencies of the network

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("auto-mpg.csv")

# Discretize continuous values using median
for column in df.columns:
    if df[column].dtype != 'object':  # Check if column is numeric
        median_val = df[column].median()  # Calculate median
        df[column] = pd.cut(df[column], bins=[float('-inf'), median_val, float('inf')], labels=['low', 'high'])

# Display first few rows of the dataset
print(df.head())
data=df
# Out:
#    mpg cylinders displacement horsepower weight acceleration model year  \
# 0  low      high         high       high   high          low        low
# 1  low      high         high       high   high          low        low
# 2  low      high         high       high   high          low        low
# 3  low      high         high       high   high          low        low
# 4  low      high         high       high   high          low        low
#
#   origin                   car name
# 0    low  chevrolet chevelle malibu
# 1    low          buick skylark 320
# 2    low         plymouth satellite
# 3    low              amc rebel sst
# 4    low                ford torino

# %%
print("[('mpg', 'displacement'), ('mpg', 'horsepower'), ('cylinders', 'acceleration'), ('displacement', 'origin'), ('displacement', 'model year'), ('horsepower', 'cylinders'), ('weight', 'mpg'), ('weight', 'displacement')]")
# Out:
# [('mpg', 'displacement'), ('mpg', 'horsepower'), ('cylinders', 'acceleration'), ('displacement', 'origin'), ('displacement', 'model year'), ('horsepower', 'cylinders'), ('weight', 'mpg'), ('weight', 'displacement')]

# %%
from pgmpy.models import BayesianNetwork

model = BayesianNetwork([('mpg', 'displacement'), ('mpg', 'horsepower'), ('cylinders', 'acceleration'), ('displacement', 'origin'), ('displacement', 'model year'), ('horsepower', 'cylinders'), ('weight', 'mpg'), ('weight', 'displacement')])

# %%
from pgmpy.estimators import ParameterEstimator
pe = ParameterEstimator(model, data)

# %%
from pgmpy.estimators import MaximumLikelihoodEstimator
mle = MaximumLikelihoodEstimator(model, data)

# %%
print(mle.estimate_cpd('mpg'))  # unconditional
# Out:
# +-----------+---------------------+-------------+
# | weight    | weight(high)        | weight(low) |
# +-----------+---------------------+-------------+
# | mpg(high) | 0.04081632653061224 | 0.94        |
# +-----------+---------------------+-------------+
# | mpg(low)  | 0.9591836734693877  | 0.06        |
# +-----------+---------------------+-------------+

# %%
# Calibrate all CPDs of `model` using MLE:
model.fit(data, estimator=MaximumLikelihoodEstimator)

# %%
from pgmpy.estimators import BayesianEstimator
est = BayesianEstimator(model, data)

# %%
print(est.estimate_cpd('acceleration', prior_type='BDeu', equivalent_sample_size=10))
# Out:
# +--------------------+---------------------+---------------------+
# | cylinders          | cylinders(high)     | cylinders(low)      |
# +--------------------+---------------------+---------------------+
# | acceleration(high) | 0.12790697674418605 | 0.7045454545454546  |
# +--------------------+---------------------+---------------------+
# | acceleration(low)  | 0.872093023255814   | 0.29545454545454547 |
# +--------------------+---------------------+---------------------+

# %%
import numpy as np
import pandas as pd
from pgmpy.models import BayesianNetwork
from pgmpy.estimators import BayesianEstimator
model = BayesianNetwork([('mpg', 'displacement'), ('mpg', 'horsepower'), ('cylinders', 'acceleration'), ('displacement', 'origin'), ('displacement', 'model year'), ('horsepower', 'cylinders'), ('weight', 'mpg'), ('weight', 'displacement')])
model.fit(data, estimator=BayesianEstimator, prior_type="BDeu") # default equivalent_sample_size=5
for cpd in model.get_cpds():
    print(cpd)
# Out:
# +-----------+---------------------+---------------------+
# | weight    | weight(high)        | weight(low)         |
# +-----------+---------------------+---------------------+
# | mpg(high) | 0.06310679611650485 | 0.919047619047619   |
# +-----------+---------------------+---------------------+
# | mpg(low)  | 0.9368932038834952  | 0.08095238095238096 |
# +-----------+---------------------+---------------------+
# +--------------------+---------------------+----------------------+---------------------+---------------------+
# | mpg                | mpg(high)           | mpg(high)            | mpg(low)            | mpg(low)            |
# +--------------------+---------------------+----------------------+---------------------+---------------------+
# | weight             | weight(high)        | weight(low)          | weight(high)        | weight(low)         |
# +--------------------+---------------------+----------------------+---------------------+---------------------+
# | displacement(high) | 0.19230769230769232 | 0.054404145077720206 | 0.966321243523316   | 0.38235294117647056 |
# +--------------------+---------------------+----------------------+---------------------+---------------------+
# | displacement(low)  | 0.8076923076923077  | 0.9455958549222798   | 0.03367875647668394 | 0.6176470588235294  |
# +--------------------+---------------------+----------------------+---------------------+---------------------+
# +------------------+----------------------+---------------------+
# | mpg              | mpg(high)            | mpg(low)            |
# +------------------+----------------------+---------------------+
# | horsepower(high) | 0.043689320388349516 | 0.8809523809523809  |
# +------------------+----------------------+---------------------+
# | horsepower(low)  | 0.9563106796116505   | 0.11904761904761904 |
# +------------------+----------------------+---------------------+
# +-----------------+---------------------+---------------------+
# | horsepower      | horsepower(high)    | horsepower(low)     |
# +-----------------+---------------------+---------------------+
# | cylinders(high) | 0.8092783505154639  | 0.02252252252252252 |
# +-----------------+---------------------+---------------------+
# | cylinders(low)  | 0.19072164948453607 | 0.9774774774774775  |
# +-----------------+---------------------+---------------------+
# +--------------------+---------------------+--------------------+
# | cylinders          | cylinders(high)     | cylinders(low)     |
# +--------------------+---------------------+--------------------+
# | acceleration(high) | 0.10493827160493827 | 0.7125984251968503 |
# +--------------------+---------------------+--------------------+
# | acceleration(low)  | 0.8950617283950617  | 0.2874015748031496 |
# +--------------------+---------------------+--------------------+
# +--------------+----------------------+--------------------+
# | displacement | displacement(high)   | displacement(low)  |
# +--------------+----------------------+--------------------+
# | origin(high) | 0.024271844660194174 | 0.7285714285714285 |
# +--------------+----------------------+--------------------+
# | origin(low)  | 0.9757281553398058   | 0.2714285714285714 |
# +--------------+----------------------+--------------------+
# +------------------+--------------------+---------------------+
# | displacement     | displacement(high) | displacement(low)   |
# +------------------+--------------------+---------------------+
# | model year(high) | 0.2766990291262136 | 0.6142857142857143  |
# +------------------+--------------------+---------------------+
# | model year(low)  | 0.7233009708737864 | 0.38571428571428573 |
# +------------------+--------------------+---------------------+
# +--------------+----------+
# | weight(high) | 0.495192 |
# +--------------+----------+
# | weight(low)  | 0.504808 |
# +--------------+----------+

# %% [markdown]
# # b. [22.5 pts] Perform parameter estimation using the Expectation Maximization algorithm. Print out CPDs and local independencies of the network.

# %%
import pandas as pd

# %%
# Load dataset
df = pd.read_csv("auto-mpg.csv")

# Discretize continuous values using median
for column in df.columns:
    if df[column].dtype != 'object':  # Check if column is numeric
        median_val = df[column].median()  # Calculate median
        df[column] = pd.cut(df[column], bins=[float('-inf'), median_val, float('inf')], labels=['low', 'high'])

# Display first few rows of the dataset
print(df.head())
data=df
# Out:
#    mpg cylinders displacement horsepower weight acceleration model year  \
# 0  low      high         high       high   high          low        low
# 1  low      high         high       high   high          low        low
# 2  low      high         high       high   high          low        low
# 3  low      high         high       high   high          low        low
# 4  low      high         high       high   high          low        low
#
#   origin                   car name
# 0    low  chevrolet chevelle malibu
# 1    low          buick skylark 320
# 2    low         plymouth satellite
# 3    low              amc rebel sst
# 4    low                ford torino

# %%
import numpy as np
import pandas as pd
from pgmpy.models import BayesianNetwork
from pgmpy.estimators import ExpectationMaximization

model = BayesianNetwork([('mpg', 'displacement'), ('mpg', 'horsepower'), ('cylinders', 'acceleration'), ('displacement', 'origin'), ('displacement', 'model year'), ('horsepower', 'cylinders'), ('weight', 'mpg'), ('weight', 'displacement')])
estimator = ExpectationMaximization(model, data)

# %%
from pgmpy.estimators import ExpectationMaximization as EM

model = BayesianNetwork([('mpg', 'displacement'), ('mpg', 'horsepower'), ('cylinders', 'acceleration'), ('displacement', 'origin'), ('displacement', 'model year'), ('horsepower', 'cylinders'), ('weight', 'mpg'), ('weight', 'displacement')])

estimator = EM(model, data)
estimator.get_parameters(latent_card={'mpg': 2})
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# [<TabularCPD representing P(mpg:2 | weight:2) at 0x216f847e9d0>,
#  <TabularCPD representing P(displacement:2 | mpg:2, weight:2) at 0x216f847ef70>,
#  <TabularCPD representing P(horsepower:2 | mpg:2) at 0x216f847e940>,
#  <TabularCPD representing P(cylinders:2 | horsepower:2) at 0x216f8486d00>,
#  <TabularCPD representing P(acceleration:2 | cylinders:2) at 0x216eb477700>,
#  <TabularCPD representing P(origin:2 | displacement:2) at 0x216f8407c10>,
#  <TabularCPD representing P(model year:2 | displacement:2) at 0x216f8407610>,
#  <TabularCPD representing P(weight:2) at 0x216f8407910>]

# %%
from pgmpy.models import BayesianNetwork
from pgmpy.independencies import IndependenceAssertion, Independencies

# Define the structure of the Bayesian network
model = BayesianNetwork([('mpg', 'displacement'), ('mpg', 'horsepower'), ('cylinders', 'acceleration'),
                         ('displacement', 'origin'), ('displacement', 'model year'), ('horsepower', 'cylinders'),
                         ('weight', 'mpg'), ('weight', 'displacement')])

# Define the independencies based on the structure
independencies = Independencies()

# Add independencies based on the structure of the Bayesian network
independencies.add_assertions(
    IndependenceAssertion('cylinders', 'displacement', ['mpg', 'horsepower']),
    IndependenceAssertion('origin', 'mpg', ['displacement', 'model year']),
    IndependenceAssertion('origin', 'mpg', ['displacement', 'model year', 'horsepower']),
    IndependenceAssertion('model year', 'mpg', ['displacement']),
    IndependenceAssertion('acceleration', 'mpg', ['cylinders', 'displacement', 'horsepower']),
    IndependenceAssertion('acceleration', 'mpg', ['cylinders', 'displacement', 'horsepower', 'weight'])
)

# Print the local independencies
print("Local independencies:")
print(independencies)
# Out:
# Local independencies:
# (cylinders ⟂ displacement | horsepower, mpg)
# (origin ⟂ mpg | displacement, model year)
# (origin ⟂ mpg | displacement, horsepower, model year)
# (model year ⟂ mpg | displacement)
# (acceleration ⟂ mpg | displacement, cylinders, horsepower)
# (acceleration ⟂ mpg | displacement, cylinders, weight, horsepower)

# %%
from pgmpy.base import DAG
chain = DAG([('mpg', 'displacement'), ('mpg', 'horsepower'), ('cylinders', 'acceleration'),
                         ('displacement', 'origin'), ('displacement', 'model year'), ('horsepower', 'cylinders'),
                         ('weight', 'mpg'), ('weight', 'displacement')])
chain.get_independencies()
# Out:
# (weight ⟂ horsepower, cylinders, acceleration | mpg)
# (weight ⟂ origin, model year | displacement)
# (weight ⟂ cylinders, acceleration | horsepower)
# (weight ⟂ acceleration | cylinders)
# (weight ⟂ horsepower, cylinders, acceleration | model year, mpg)
# (weight ⟂ origin | displacement, model year)
# (weight ⟂ cylinders, acceleration | horsepower, model year)
# (weight ⟂ acceleration | cylinders, model year)
# (weight ⟂ model year, origin, horsepower, cylinders, acceleration | displacement, mpg)
# (weight ⟂ cylinders, acceleration | horsepower, mpg)
# (weight ⟂ horsepower, cylinders, acceleration | origin, mpg)
# (weight ⟂ horsepower, acceleration | cylinders, mpg)
# (weight ⟂ horsepower, cylinders | acceleration, mpg)
# (weight ⟂ origin, cylinders, model year, acceleration | displacement, horsepower)
# (weight ⟂ model year | displacement, origin)
# (weight ⟂ origin, model year, acceleration | displacement, cylinders)
# (weight ⟂ origin, model year | displacement, acceleration)
# (weight ⟂ cylinders, acceleration | origin, horsepower)
# (weight ⟂ acceleration | horsepower, cylinders)
# (weight ⟂ cylinders | horsepower, acceleration)
# (weight ⟂ acceleration | origin, cylinders)
# (weight ⟂ origin, horsepower, cylinders, acceleration | displacement, model year, mpg)
# (weight ⟂ cylinders, acceleration | horsepower, model year, mpg)
# (weight ⟂ horsepower, cylinders, acceleration | origin, model year, mpg)
# (weight ⟂ horsepower, acceleration | cylinders, model year, mpg)
# (weight ⟂ horsepower, cylinders | model year, acceleration, mpg)
# (weight ⟂ origin, cylinders, acceleration | displacement, horsepower, model year)
# (weight ⟂ origin, acceleration | displacement, cylinders, model year)
# (weight ⟂ origin | displacement, model year, acceleration)
# (weight ⟂ cylinders, acceleration | origin, horsepower, model year)
# (weight ⟂ acceleration | horsepower, model year, cylinders)
# (weight ⟂ cylinders | horsepower, model year, acceleration)
# (weight ⟂ acceleration | origin, cylinders, model year)
# (weight ⟂ origin, cylinders, model year, acceleration | displacement, horsepower, mpg)
# (weight ⟂ horsepower, model year, cylinders, acceleration | displacement, origin, mpg)
# (weight ⟂ origin, horsepower, model year, acceleration | displacement, cylinders, mpg)
# (weight ⟂ origin, horsepower, model year, cylinders | displacement, acceleration, mpg)
# (weight ⟂ cylinders, acceleration | origin, horsepower, mpg)
# (weight ⟂ acceleration | horsepower, cylinders, mpg)
# (weight ⟂ cylinders | horsepower, acceleration, mpg)
# (weight ⟂ horsepower, acceleration | origin, cylinders, mpg)
# (weight ⟂ horsepower, cylinders | origin, acceleration, mpg)
# (weight ⟂ horsepower | cylinders, acceleration, mpg)
# (weight ⟂ cylinders, model year, acceleration | displacement, horsepower, origin)
# (weight ⟂ origin, model year, acceleration | displacement, horsepower, cylinders)
# (weight ⟂ origin, cylinders, model year | displacement, horsepower, acceleration)
# (weight ⟂ model year, acceleration | displacement, cylinders, origin)
# (weight ⟂ model year | displacement, origin, acceleration)
# (weight ⟂ origin, model year | displacement, cylinders, acceleration)
# (weight ⟂ acceleration | origin, horsepower, cylinders)
# (weight ⟂ cylinders | origin, horsepower, acceleration)
# (weight ⟂ origin, cylinders, acceleration | displacement, horsepower, model year, mpg)
# (weight ⟂ horsepower, cylinders, acceleration | displacement, model year, origin, mpg)
# (weight ⟂ origin, horsepower, acceleration | displacement, cylinders, model year, mpg)
# (weight ⟂ origin, horsepower, cylinders | displacement, model year, acceleration, mpg)
# (weight ⟂ cylinders, acceleration | origin, horsepower, model year, mpg)
# (weight ⟂ acceleration | horsepower, model year, cylinders, mpg)
# (weight ⟂ cylinders | horsepower, model year, acceleration, mpg)
# (weight ⟂ horsepower, acceleration | origin, cylinders, model year, mpg)
# (weight ⟂ horsepower, cylinders | origin, model year, acceleration, mpg)
# (weight ⟂ horsepower | cylinders, model year, acceleration, mpg)
# (weight ⟂ cylinders, acceleration | displacement, horsepower, model year, origin)
# (weight ⟂ origin, acceleration | displacement, horsepower, model year, cylinders)
# (weight ⟂ origin, cylinders | displacement, horsepower, model year, acceleration)
# (weight ⟂ acceleration | displacement, cylinders, model year, origin)
# (weight ⟂ origin | displacement, cylinders, model year, acceleration)
# (weight ⟂ acceleration | origin, horsepower, model year, cylinders)
# (weight ⟂ cylinders | origin, horsepower, model year, acceleration)
# (weight ⟂ cylinders, model year, acceleration | displacement, horsepower, origin, mpg)
# (weight ⟂ origin, model year, acceleration | displacement, horsepower, cylinders, mpg)
# (weight ⟂ origin, cylinders, model year | displacement, horsepower, acceleration, mpg)
# (weight ⟂ horsepower, model year, acceleration | displacement, cylinders, origin, mpg)
# (weight ⟂ horsepower, model year, cylinders | displacement, origin, acceleration, mpg)
# (weight ⟂ origin, horsepower, model year | displacement, cylinders, acceleration, mpg)
# (weight ⟂ acceleration | origin, horsepower, cylinders, mpg)
# (weight ⟂ cylinders | origin, horsepower, acceleration, mpg)
# (weight ⟂ horsepower | origin, cylinders, acceleration, mpg)
# (weight ⟂ model year, acceleration | displacement, horsepower, origin, cylinders)
# (weight ⟂ cylinders, model year | displacement, horsepower, origin, acceleration)
# (weight ⟂ origin, model year | displacement, horsepower, cylinders, acceleration)
# (weight ⟂ model year | displacement, cylinders, origin, acceleration)
# (weight ⟂ cylinders, acceleration | model year, displacement, horsepower, mpg, origin)
# (weight ⟂ origin, acceleration | model year, displacement, horsepower, cylinders, mpg)
# (weight ⟂ origin, cylinders | model year, displacement, horsepower, mpg, acceleration)
# (weight ⟂ horsepower, acceleration | model year, displacement, cylinders, mpg, origin)
# (weight ⟂ horsepower, cylinders | model year, displacement, mpg, origin, acceleration)
# (weight ⟂ origin, horsepower | model year, displacement, cylinders, mpg, acceleration)
# (weight ⟂ acceleration | model year, horsepower, cylinders, mpg, origin)
# (weight ⟂ cylinders | model year, horsepower, mpg, origin, acceleration)
# (weight ⟂ horsepower | model year, cylinders, mpg, origin, acceleration)
# (weight ⟂ acceleration | model year, displacement, horsepower, cylinders, origin)
# (weight ⟂ cylinders | model year, displacement, horsepower, origin, acceleration)
# (weight ⟂ origin | model year, displacement, horsepower, cylinders, acceleration)
# (weight ⟂ model year, acceleration | displacement, horsepower, cylinders, mpg, origin)
# (weight ⟂ cylinders, model year | displacement, horsepower, mpg, origin, acceleration)
# (weight ⟂ origin, model year | displacement, horsepower, cylinders, mpg, acceleration)
# (weight ⟂ horsepower, model year | displacement, cylinders, mpg, origin, acceleration)
# (weight ⟂ model year | displacement, horsepower, cylinders, origin, acceleration)
# (weight ⟂ acceleration | model year, displacement, horsepower, cylinders, mpg, origin)
# (weight ⟂ cylinders | model year, displacement, horsepower, mpg, origin, acceleration)
# (weight ⟂ origin | model year, displacement, horsepower, cylinders, mpg, acceleration)
# (weight ⟂ horsepower | model year, displacement, cylinders, mpg, origin, acceleration)
# (weight ⟂ model year | displacement, horsepower, cylinders, mpg, origin, acceleration)
# (model year ⟂ cylinders, acceleration, horsepower | mpg)
# (model year ⟂ weight, horsepower, mpg, origin, cylinders, acceleration | displacement)
# (model year ⟂ cylinders, acceleration | horsepower)
# (model year ⟂ acceleration | cylinders)
# (model year ⟂ horsepower, cylinders, acceleration | weight, mpg)
# (model year ⟂ mpg, origin, horsepower, cylinders, acceleration | displacement, weight)
# (model year ⟂ cylinders, acceleration | weight, horsepower)
# (model year ⟂ acceleration | weight, cylinders)
# (model year ⟂ weight, horsepower, origin, cylinders, acceleration | displacement, mpg)
# (model year ⟂ cylinders, acceleration | horsepower, mpg)
# (model year ⟂ cylinders, acceleration, horsepower | origin, mpg)
# (model year ⟂ horsepower, acceleration | cylinders, mpg)
# (model year ⟂ cylinders, horsepower | acceleration, mpg)
# (model year ⟂ weight, mpg, origin, cylinders, acceleration | displacement, horsepower)
# (model year ⟂ weight, horsepower, mpg, cylinders, acceleration | displacement, origin)
# (model year ⟂ weight, mpg, origin, horsepower, acceleration | displacement, cylinders)
# (model year ⟂ weight, horsepower, mpg, origin, cylinders | displacement, acceleration)
# (model year ⟂ cylinders, acceleration | origin, horsepower)
# (model year ⟂ acceleration | horsepower, cylinders)
# (model year ⟂ cylinders | horsepower, acceleration)
# (model year ⟂ acceleration | origin, cylinders)
# (model year ⟂ origin, horsepower, cylinders, acceleration | displacement, weight, mpg)
# (model year ⟂ cylinders, acceleration | weight, horsepower, mpg)
# (model year ⟂ horsepower, cylinders, acceleration | origin, weight, mpg)
# (model year ⟂ horsepower, acceleration | weight, cylinders, mpg)
# (model year ⟂ horsepower, cylinders | weight, acceleration, mpg)
# (model year ⟂ origin, cylinders, acceleration, mpg | displacement, weight, horsepower)
# (model year ⟂ horsepower, cylinders, acceleration, mpg | displacement, weight, origin)
# (model year ⟂ origin, horsepower, acceleration, mpg | displacement, weight, cylinders)
# (model year ⟂ origin, horsepower, cylinders, mpg | displacement, weight, acceleration)
# (model year ⟂ cylinders, acceleration | origin, weight, horsepower)
# (model year ⟂ acceleration | weight, cylinders, horsepower)
# (model year ⟂ cylinders | weight, acceleration, horsepower)
# (model year ⟂ acceleration | origin, weight, cylinders)
# (model year ⟂ origin, weight, cylinders, acceleration | displacement, horsepower, mpg)
# (model year ⟂ weight, cylinders, horsepower, acceleration | displacement, origin, mpg)
# (model year ⟂ origin, weight, horsepower, acceleration | displacement, cylinders, mpg)
# (model year ⟂ origin, weight, cylinders, horsepower | displacement, acceleration, mpg)
# (model year ⟂ cylinders, acceleration | origin, horsepower, mpg)
# (model year ⟂ acceleration | horsepower, cylinders, mpg)
# (model year ⟂ cylinders | horsepower, acceleration, mpg)
# (model year ⟂ horsepower, acceleration | origin, cylinders, mpg)
# (model year ⟂ cylinders, horsepower | origin, acceleration, mpg)
# (model year ⟂ horsepower | cylinders, acceleration, mpg)
# (model year ⟂ weight, cylinders, acceleration, mpg | displacement, horsepower, origin)
# (model year ⟂ origin, weight, acceleration, mpg | displacement, horsepower, cylinders)
# (model year ⟂ origin, weight, cylinders, mpg | displacement, horsepower, acceleration)
# (model year ⟂ weight, horsepower, acceleration, mpg | displacement, cylinders, origin)
# (model year ⟂ weight, cylinders, horsepower, mpg | displacement, origin, acceleration)
# (model year ⟂ origin, weight, horsepower, mpg | displacement, cylinders, acceleration)
# (model year ⟂ acceleration | origin, horsepower, cylinders)
# (model year ⟂ cylinders | origin, horsepower, acceleration)
# (model year ⟂ origin, cylinders, acceleration | displacement, weight, horsepower, mpg)
# (model year ⟂ horsepower, cylinders, acceleration | displacement, weight, origin, mpg)
# (model year ⟂ origin, horsepower, acceleration | displacement, weight, cylinders, mpg)
# (model year ⟂ origin, horsepower, cylinders | displacement, weight, acceleration, mpg)
# (model year ⟂ cylinders, acceleration | origin, weight, horsepower, mpg)
# (model year ⟂ acceleration | weight, cylinders, horsepower, mpg)
# (model year ⟂ cylinders | weight, acceleration, horsepower, mpg)
# (model year ⟂ horsepower, acceleration | origin, weight, cylinders, mpg)
# (model year ⟂ horsepower, cylinders | origin, weight, acceleration, mpg)
# (model year ⟂ horsepower | weight, cylinders, acceleration, mpg)
# (model year ⟂ cylinders, acceleration, mpg | displacement, weight, origin, horsepower)
# (model year ⟂ origin, acceleration, mpg | displacement, weight, cylinders, horsepower)
# (model year ⟂ origin, cylinders, mpg | displacement, weight, acceleration, horsepower)
# (model year ⟂ horsepower, acceleration, mpg | displacement, weight, origin, cylinders)
# (model year ⟂ horsepower, cylinders, mpg | displacement, weight, origin, acceleration)
# (model year ⟂ origin, horsepower, mpg | displacement, weight, cylinders, acceleration)
# (model year ⟂ acceleration | origin, weight, cylinders, horsepower)
# (model year ⟂ cylinders | origin, weight, acceleration, horsepower)
# (model year ⟂ weight, cylinders, acceleration | displacement, horsepower, origin, mpg)
# (model year ⟂ origin, weight, acceleration | displacement, horsepower, cylinders, mpg)
# (model year ⟂ origin, weight, cylinders | displacement, horsepower, acceleration, mpg)
# (model year ⟂ weight, horsepower, acceleration | displacement, cylinders, origin, mpg)
# (model year ⟂ weight, cylinders, horsepower | displacement, origin, acceleration, mpg)
# (model year ⟂ origin, weight, horsepower | displacement, cylinders, acceleration, mpg)
# (model year ⟂ acceleration | origin, horsepower, cylinders, mpg)
# (model year ⟂ cylinders | origin, horsepower, acceleration, mpg)
# (model year ⟂ horsepower | origin, cylinders, acceleration, mpg)
# (model year ⟂ weight, acceleration, mpg | displacement, horsepower, origin, cylinders)
# (model year ⟂ weight, cylinders, mpg | displacement, horsepower, origin, acceleration)
# (model year ⟂ origin, weight, mpg | displacement, horsepower, cylinders, acceleration)
# (model year ⟂ weight, horsepower, mpg | displacement, cylinders, origin, acceleration)
# (model year ⟂ cylinders, acceleration | weight, displacement, horsepower, mpg, origin)
# (model year ⟂ origin, acceleration | weight, displacement, cylinders, horsepower, mpg)
# (model year ⟂ origin, cylinders | weight, displacement, horsepower, mpg, acceleration)
# (model year ⟂ horsepower, acceleration | weight, displacement, cylinders, mpg, origin)
# (model year ⟂ horsepower, cylinders | weight, displacement, mpg, origin, acceleration)
# (model year ⟂ origin, horsepower | weight, displacement, cylinders, mpg, acceleration)
# (model year ⟂ acceleration | weight, cylinders, horsepower, mpg, origin)
# (model year ⟂ cylinders | weight, horsepower, mpg, origin, acceleration)
# (model year ⟂ horsepower | weight, cylinders, mpg, origin, acceleration)
# (model year ⟂ acceleration, mpg | weight, displacement, cylinders, horsepower, origin)
# (model year ⟂ cylinders, mpg | weight, displacement, horsepower, origin, acceleration)
# (model year ⟂ origin, mpg | weight, displacement, cylinders, horsepower, acceleration)
# (model year ⟂ horsepower, mpg | weight, displacement, cylinders, origin, acceleration)
# (model year ⟂ weight, acceleration | displacement, horsepower, cylinders, mpg, origin)
# (model year ⟂ weight, cylinders | displacement, horsepower, mpg, origin, acceleration)
# (model year ⟂ origin, weight | displacement, horsepower, cylinders, mpg, acceleration)
# (model year ⟂ weight, horsepower | displacement, cylinders, mpg, origin, acceleration)
# (model year ⟂ weight, mpg | displacement, horsepower, cylinders, origin, acceleration)
# (model year ⟂ acceleration | weight, displacement, horsepower, cylinders, mpg, origin)
# (model year ⟂ cylinders | weight, displacement, horsepower, mpg, origin, acceleration)
# (model year ⟂ origin | weight, displacement, cylinders, horsepower, mpg, acceleration)
# (model year ⟂ horsepower | weight, displacement, cylinders, mpg, origin, acceleration)
# (model year ⟂ mpg | weight, displacement, cylinders, horsepower, origin, acceleration)
# (model year ⟂ weight | displacement, horsepower, cylinders, mpg, origin, acceleration)
# (displacement ⟂ cylinders, acceleration, horsepower | mpg)
# (displacement ⟂ cylinders, acceleration | horsepower)
# (displacement ⟂ acceleration | cylinders)
# (displacement ⟂ horsepower, cylinders, acceleration | weight, mpg)
# (displacement ⟂ cylinders, acceleration | weight, horsepower)
# (displacement ⟂ acceleration | weight, cylinders)
# (displacement ⟂ cylinders, acceleration, horsepower | model year, mpg)
# (displacement ⟂ cylinders, acceleration | horsepower, model year)
# (displacement ⟂ acceleration | cylinders, model year)
# (displacement ⟂ cylinders, acceleration, horsepower | origin, mpg)
# (displacement ⟂ cylinders, acceleration | horsepower, mpg)
# (displacement ⟂ horsepower, acceleration | cylinders, mpg)
# (displacement ⟂ cylinders, horsepower | acceleration, mpg)
# (displacement ⟂ cylinders, acceleration | origin, horsepower)
# (displacement ⟂ acceleration | origin, cylinders)
# (displacement ⟂ acceleration | horsepower, cylinders)
# (displacement ⟂ cylinders | horsepower, acceleration)
# (displacement ⟂ horsepower, cylinders, acceleration | weight, model year, mpg)
# (displacement ⟂ cylinders, acceleration | weight, model year, horsepower)
# (displacement ⟂ acceleration | weight, model year, cylinders)
# (displacement ⟂ horsepower, cylinders, acceleration | origin, weight, mpg)
# (displacement ⟂ cylinders, acceleration | weight, horsepower, mpg)
# (displacement ⟂ horsepower, acceleration | weight, cylinders, mpg)
# (displacement ⟂ horsepower, cylinders | weight, acceleration, mpg)
# (displacement ⟂ cylinders, acceleration | origin, weight, horsepower)
# (displacement ⟂ acceleration | origin, weight, cylinders)
# (displacement ⟂ acceleration | weight, cylinders, horsepower)
# (displacement ⟂ cylinders | weight, acceleration, horsepower)
# (displacement ⟂ cylinders, horsepower, acceleration | origin, model year, mpg)
# (displacement ⟂ cylinders, acceleration | horsepower, model year, mpg)
# (displacement ⟂ horsepower, acceleration | cylinders, model year, mpg)
# (displacement ⟂ cylinders, horsepower | model year, acceleration, mpg)
# (displacement ⟂ cylinders, acceleration | origin, horsepower, model year)
# (displacement ⟂ acceleration | origin, cylinders, model year)
# (displacement ⟂ acceleration | horsepower, model year, cylinders)
# (displacement ⟂ cylinders | horsepower, model year, acceleration)
# (displacement ⟂ cylinders, acceleration | origin, horsepower, mpg)
# (displacement ⟂ horsepower, acceleration | origin, cylinders, mpg)
# (displacement ⟂ cylinders, horsepower | origin, acceleration, mpg)
# (displacement ⟂ acceleration | horsepower, cylinders, mpg)
# (displacement ⟂ cylinders | horsepower, acceleration, mpg)
# (displacement ⟂ horsepower | cylinders, acceleration, mpg)
# (displacement ⟂ acceleration | origin, horsepower, cylinders)
# (displacement ⟂ cylinders | origin, horsepower, acceleration)
# (displacement ⟂ horsepower, cylinders, acceleration | origin, weight, model year, mpg)
# (displacement ⟂ cylinders, acceleration | weight, model year, horsepower, mpg)
# (displacement ⟂ horsepower, acceleration | weight, model year, cylinders, mpg)
# (displacement ⟂ horsepower, cylinders | weight, model year, acceleration, mpg)
# (displacement ⟂ cylinders, acceleration | origin, weight, model year, horsepower)
# (displacement ⟂ acceleration | origin, weight, model year, cylinders)
# (displacement ⟂ acceleration | weight, model year, cylinders, horsepower)
# (displacement ⟂ cylinders | weight, model year, acceleration, horsepower)
# (displacement ⟂ cylinders, acceleration | origin, weight, horsepower, mpg)
# (displacement ⟂ horsepower, acceleration | origin, weight, cylinders, mpg)
# (displacement ⟂ horsepower, cylinders | origin, weight, acceleration, mpg)
# (displacement ⟂ acceleration | weight, cylinders, horsepower, mpg)
# (displacement ⟂ cylinders | weight, acceleration, horsepower, mpg)
# (displacement ⟂ horsepower | weight, cylinders, acceleration, mpg)
# (displacement ⟂ acceleration | origin, weight, cylinders, horsepower)
# (displacement ⟂ cylinders | origin, weight, acceleration, horsepower)
# (displacement ⟂ cylinders, acceleration | origin, horsepower, model year, mpg)
# (displacement ⟂ horsepower, acceleration | origin, cylinders, model year, mpg)
# (displacement ⟂ cylinders, horsepower | origin, model year, acceleration, mpg)
# (displacement ⟂ acceleration | horsepower, model year, cylinders, mpg)
# (displacement ⟂ cylinders | horsepower, model year, acceleration, mpg)
# (displacement ⟂ horsepower | cylinders, model year, acceleration, mpg)
# (displacement ⟂ acceleration | origin, horsepower, model year, cylinders)
# (displacement ⟂ cylinders | origin, horsepower, model year, acceleration)
# (displacement ⟂ acceleration | origin, horsepower, cylinders, mpg)
# (displacement ⟂ cylinders | origin, horsepower, acceleration, mpg)
# (displacement ⟂ horsepower | origin, cylinders, acceleration, mpg)
# (displacement ⟂ cylinders, acceleration | weight, model year, horsepower, mpg, origin)
# (displacement ⟂ horsepower, acceleration | weight, model year, cylinders, mpg, origin)
# (displacement ⟂ horsepower, cylinders | weight, model year, mpg, origin, acceleration)
# (displacement ⟂ acceleration | weight, model year, cylinders, horsepower, mpg)
# (displacement ⟂ cylinders | weight, model year, horsepower, mpg, acceleration)
# (displacement ⟂ horsepower | weight, model year, cylinders, mpg, acceleration)
# (displacement ⟂ acceleration | weight, model year, cylinders, horsepower, origin)
# (displacement ⟂ cylinders | weight, model year, horsepower, origin, acceleration)
# (displacement ⟂ acceleration | weight, cylinders, horsepower, mpg, origin)
# (displacement ⟂ cylinders | weight, horsepower, mpg, origin, acceleration)
# (displacement ⟂ horsepower | weight, cylinders, mpg, origin, acceleration)
# (displacement ⟂ acceleration | model year, horsepower, cylinders, mpg, origin)
# (displacement ⟂ cylinders | model year, horsepower, mpg, origin, acceleration)
# (displacement ⟂ horsepower | model year, cylinders, mpg, origin, acceleration)
# (displacement ⟂ acceleration | weight, model year, horsepower, cylinders, mpg, origin)
# (displacement ⟂ cylinders | weight, model year, horsepower, mpg, origin, acceleration)
# (displacement ⟂ horsepower | weight, model year, cylinders, mpg, origin, acceleration)
# (horsepower ⟂ displacement, weight, model year, origin | mpg)
# (horsepower ⟂ origin, model year | displacement)
# (horsepower ⟂ acceleration | cylinders)
# (horsepower ⟂ displacement, model year, origin | weight, mpg)
# (horsepower ⟂ origin, model year | displacement, weight)
# (horsepower ⟂ acceleration | weight, cylinders)
# (horsepower ⟂ displacement, weight, origin | model year, mpg)
# (horsepower ⟂ origin | displacement, model year)
# (horsepower ⟂ acceleration | cylinders, model year)
# (horsepower ⟂ origin, weight, model year | displacement, mpg)
# (horsepower ⟂ weight, model year, displacement, origin, acceleration | cylinders, mpg)
# (horsepower ⟂ displacement, weight, model year | origin, mpg)
# (horsepower ⟂ displacement, weight, model year, origin | acceleration, mpg)
# (horsepower ⟂ origin, model year, acceleration | displacement, cylinders)
# (horsepower ⟂ model year | displacement, origin)
# (horsepower ⟂ origin, model year | displacement, acceleration)
# (horsepower ⟂ acceleration | origin, cylinders)
# (horsepower ⟂ displacement, origin | weight, model year, mpg)
# (horsepower ⟂ origin | displacement, weight, model year)
# (horsepower ⟂ acceleration | weight, model year, cylinders)
# (horsepower ⟂ origin, model year | displacement, weight, mpg)
# (horsepower ⟂ displacement, model year, origin, acceleration | weight, cylinders, mpg)
# (horsepower ⟂ displacement, model year | origin, weight, mpg)
# (horsepower ⟂ displacement, model year, origin | weight, acceleration, mpg)
# (horsepower ⟂ origin, model year, acceleration | displacement, weight, cylinders)
# (horsepower ⟂ model year | displacement, weight, origin)
# (horsepower ⟂ origin, model year | displacement, weight, acceleration)
# (horsepower ⟂ acceleration | origin, weight, cylinders)
# (horsepower ⟂ origin, weight | displacement, model year, mpg)
# (horsepower ⟂ displacement, weight, origin, acceleration | cylinders, model year, mpg)
# (horsepower ⟂ displacement, weight | origin, model year, mpg)
# (horsepower ⟂ displacement, weight, origin | model year, acceleration, mpg)
# (horsepower ⟂ origin, acceleration | displacement, cylinders, model year)
# (horsepower ⟂ origin | displacement, model year, acceleration)
# (horsepower ⟂ acceleration | origin, cylinders, model year)
# (horsepower ⟂ origin, weight, model year, acceleration | displacement, cylinders, mpg)
# (horsepower ⟂ weight, model year | displacement, origin, mpg)
# (horsepower ⟂ origin, weight, model year | displacement, acceleration, mpg)
# (horsepower ⟂ displacement, weight, model year, acceleration | origin, cylinders, mpg)
# (horsepower ⟂ displacement, weight, model year, origin | cylinders, acceleration, mpg)
# (horsepower ⟂ displacement, weight, model year | origin, acceleration, mpg)
# (horsepower ⟂ model year, acceleration | displacement, cylinders, origin)
# (horsepower ⟂ origin, model year | displacement, cylinders, acceleration)
# (horsepower ⟂ model year | displacement, origin, acceleration)
# (horsepower ⟂ origin | displacement, weight, model year, mpg)
# (horsepower ⟂ displacement, origin, acceleration | weight, model year, cylinders, mpg)
# (horsepower ⟂ displacement | origin, weight, model year, mpg)
# (horsepower ⟂ displacement, origin | weight, model year, acceleration, mpg)
# (horsepower ⟂ origin, acceleration | displacement, weight, model year, cylinders)
# (horsepower ⟂ origin | displacement, weight, model year, acceleration)
# (horsepower ⟂ acceleration | origin, weight, model year, cylinders)
# (horsepower ⟂ origin, model year, acceleration | displacement, weight, cylinders, mpg)
# (horsepower ⟂ model year | displacement, weight, origin, mpg)
# (horsepower ⟂ origin, model year | displacement, weight, acceleration, mpg)
# (horsepower ⟂ displacement, model year, acceleration | origin, weight, cylinders, mpg)
# (horsepower ⟂ displacement, model year, origin | weight, cylinders, acceleration, mpg)
# (horsepower ⟂ displacement, model year | origin, weight, acceleration, mpg)
# (horsepower ⟂ model year, acceleration | displacement, weight, origin, cylinders)
# (horsepower ⟂ origin, model year | displacement, weight, cylinders, acceleration)
# (horsepower ⟂ model year | displacement, weight, origin, acceleration)
# (horsepower ⟂ origin, weight, acceleration | displacement, cylinders, model year, mpg)
# (horsepower ⟂ weight | displacement, model year, origin, mpg)
# (horsepower ⟂ origin, weight | displacement, model year, acceleration, mpg)
# (horsepower ⟂ displacement, weight, acceleration | origin, cylinders, model year, mpg)
# (horsepower ⟂ displacement, weight, origin | cylinders, model year, acceleration, mpg)
# (horsepower ⟂ displacement, weight | origin, model year, acceleration, mpg)
# (horsepower ⟂ acceleration | displacement, cylinders, model year, origin)
# (horsepower ⟂ origin | displacement, cylinders, model year, acceleration)
# (horsepower ⟂ weight, model year, acceleration | displacement, cylinders, origin, mpg)
# (horsepower ⟂ origin, weight, model year | displacement, cylinders, acceleration, mpg)
# (horsepower ⟂ weight, model year | displacement, origin, acceleration, mpg)
# (horsepower ⟂ displacement, weight, model year | origin, cylinders, acceleration, mpg)
# (horsepower ⟂ model year | displacement, cylinders, origin, acceleration)
# (horsepower ⟂ origin, acceleration | weight, model year, displacement, cylinders, mpg)
# (horsepower ⟂ origin | weight, model year, displacement, mpg, acceleration)
# (horsepower ⟂ displacement, acceleration | weight, model year, cylinders, mpg, origin)
# (horsepower ⟂ displacement, origin | weight, model year, cylinders, mpg, acceleration)
# (horsepower ⟂ displacement | weight, model year, mpg, origin, acceleration)
# (horsepower ⟂ acceleration | weight, model year, displacement, cylinders, origin)
# (horsepower ⟂ origin | weight, model year, displacement, cylinders, acceleration)
# (horsepower ⟂ model year, acceleration | weight, displacement, cylinders, mpg, origin)
# (horsepower ⟂ origin, model year | weight, displacement, cylinders, mpg, acceleration)
# (horsepower ⟂ model year | weight, displacement, mpg, origin, acceleration)
# (horsepower ⟂ displacement, model year | weight, cylinders, mpg, origin, acceleration)
# (horsepower ⟂ model year | weight, displacement, cylinders, origin, acceleration)
# (horsepower ⟂ weight, acceleration | model year, displacement, cylinders, mpg, origin)
# (horsepower ⟂ origin, weight | model year, displacement, cylinders, mpg, acceleration)
# (horsepower ⟂ weight | model year, displacement, mpg, origin, acceleration)
# (horsepower ⟂ displacement, weight | model year, cylinders, mpg, origin, acceleration)
# (horsepower ⟂ weight, model year | displacement, cylinders, mpg, origin, acceleration)
# (horsepower ⟂ acceleration | weight, model year, displacement, cylinders, mpg, origin)
# (horsepower ⟂ origin | weight, model year, displacement, cylinders, mpg, acceleration)
# (horsepower ⟂ displacement | weight, model year, cylinders, mpg, origin, acceleration)
# (horsepower ⟂ model year | weight, displacement, cylinders, mpg, origin, acceleration)
# (horsepower ⟂ weight | model year, displacement, cylinders, mpg, origin, acceleration)
# (cylinders ⟂ displacement, weight, model year, origin | mpg)
# (cylinders ⟂ origin, model year | displacement)
# (cylinders ⟂ weight, model year, mpg, displacement, origin | horsepower)
# (cylinders ⟂ displacement, model year, origin | weight, mpg)
# (cylinders ⟂ origin, model year | displacement, weight)
# (cylinders ⟂ displacement, model year, origin, mpg | weight, horsepower)
# (cylinders ⟂ displacement, weight, origin | model year, mpg)
# (cylinders ⟂ origin | displacement, model year)
# (cylinders ⟂ displacement, weight, origin, mpg | horsepower, model year)
# (cylinders ⟂ origin, weight, model year | displacement, mpg)
# (cylinders ⟂ displacement, weight, model year, origin | horsepower, mpg)
# (cylinders ⟂ displacement, weight, model year | origin, mpg)
# (cylinders ⟂ displacement, weight, model year, origin | acceleration, mpg)
# (cylinders ⟂ origin, weight, model year, mpg | displacement, horsepower)
# (cylinders ⟂ model year | displacement, origin)
# (cylinders ⟂ origin, model year | displacement, acceleration)
# (cylinders ⟂ displacement, weight, model year, mpg | origin, horsepower)
# (cylinders ⟂ weight, model year, mpg, displacement, origin | horsepower, acceleration)
# (cylinders ⟂ displacement, origin | weight, model year, mpg)
# (cylinders ⟂ origin | displacement, weight, model year)
# (cylinders ⟂ displacement, origin, mpg | weight, model year, horsepower)
# (cylinders ⟂ origin, model year | displacement, weight, mpg)
# (cylinders ⟂ displacement, model year, origin | weight, horsepower, mpg)
# (cylinders ⟂ displacement, model year | origin, weight, mpg)
# (cylinders ⟂ displacement, model year, origin | weight, acceleration, mpg)
# (cylinders ⟂ origin, model year, mpg | displacement, weight, horsepower)
# (cylinders ⟂ model year | displacement, weight, origin)
# (cylinders ⟂ origin, model year | displacement, weight, acceleration)
# (cylinders ⟂ displacement, model year, mpg | origin, weight, horsepower)
# (cylinders ⟂ displacement, model year, origin, mpg | weight, acceleration, horsepower)
# (cylinders ⟂ origin, weight | displacement, model year, mpg)
# (cylinders ⟂ displacement, weight, origin | horsepower, model year, mpg)
# (cylinders ⟂ displacement, weight | origin, model year, mpg)
# (cylinders ⟂ displacement, weight, origin | model year, acceleration, mpg)
# (cylinders ⟂ origin, weight, mpg | displacement, horsepower, model year)
# (cylinders ⟂ origin | displacement, model year, acceleration)
# (cylinders ⟂ displacement, weight, mpg | origin, horsepower, model year)
# (cylinders ⟂ displacement, weight, origin, mpg | horsepower, model year, acceleration)
# (cylinders ⟂ origin, weight, model year | displacement, horsepower, mpg)
# (cylinders ⟂ weight, model year | displacement, origin, mpg)
# (cylinders ⟂ origin, weight, model year | displacement, acceleration, mpg)
# (cylinders ⟂ displacement, weight, model year | origin, horsepower, mpg)
# (cylinders ⟂ displacement, weight, model year, origin | horsepower, acceleration, mpg)
# (cylinders ⟂ displacement, weight, model year | origin, acceleration, mpg)
# (cylinders ⟂ weight, model year, mpg | displacement, horsepower, origin)
# (cylinders ⟂ origin, weight, model year, mpg | displacement, horsepower, acceleration)
# (cylinders ⟂ model year | displacement, origin, acceleration)
# (cylinders ⟂ displacement, weight, model year, mpg | origin, horsepower, acceleration)
# (cylinders ⟂ origin | displacement, weight, model year, mpg)
# (cylinders ⟂ displacement, origin | weight, model year, horsepower, mpg)
# (cylinders ⟂ displacement | origin, weight, model year, mpg)
# (cylinders ⟂ displacement, origin | weight, model year, acceleration, mpg)
# (cylinders ⟂ origin, mpg | displacement, weight, model year, horsepower)
# (cylinders ⟂ origin | displacement, weight, model year, acceleration)
# (cylinders ⟂ displacement, mpg | origin, weight, model year, horsepower)
# (cylinders ⟂ displacement, origin, mpg | weight, model year, acceleration, horsepower)
# (cylinders ⟂ origin, model year | displacement, weight, horsepower, mpg)
# (cylinders ⟂ model year | displacement, weight, origin, mpg)
# (cylinders ⟂ origin, model year | displacement, weight, acceleration, mpg)
# (cylinders ⟂ displacement, model year | origin, weight, horsepower, mpg)
# (cylinders ⟂ displacement, model year, origin | weight, acceleration, horsepower, mpg)
# (cylinders ⟂ displacement, model year | origin, weight, acceleration, mpg)
# (cylinders ⟂ model year, mpg | displacement, weight, origin, horsepower)
# (cylinders ⟂ origin, model year, mpg | displacement, weight, acceleration, horsepower)
# (cylinders ⟂ model year | displacement, weight, origin, acceleration)
# (cylinders ⟂ displacement, model year, mpg | origin, weight, acceleration, horsepower)
# (cylinders ⟂ origin, weight | displacement, horsepower, model year, mpg)
# (cylinders ⟂ weight | displacement, model year, origin, mpg)
# (cylinders ⟂ origin, weight | displacement, model year, acceleration, mpg)
# (cylinders ⟂ displacement, weight | origin, horsepower, model year, mpg)
# (cylinders ⟂ displacement, weight, origin | horsepower, model year, acceleration, mpg)
# (cylinders ⟂ displacement, weight | origin, model year, acceleration, mpg)
# (cylinders ⟂ weight, mpg | displacement, horsepower, model year, origin)
# (cylinders ⟂ origin, weight, mpg | displacement, horsepower, model year, acceleration)
# (cylinders ⟂ displacement, weight, mpg | origin, horsepower, model year, acceleration)
# (cylinders ⟂ weight, model year | displacement, horsepower, origin, mpg)
# (cylinders ⟂ origin, weight, model year | displacement, horsepower, acceleration, mpg)
# (cylinders ⟂ weight, model year | displacement, origin, acceleration, mpg)
# (cylinders ⟂ displacement, weight, model year | origin, horsepower, acceleration, mpg)
# (cylinders ⟂ weight, model year, mpg | displacement, horsepower, origin, acceleration)
# (cylinders ⟂ origin | weight, model year, displacement, horsepower, mpg)
# (cylinders ⟂ origin | weight, model year, displacement, mpg, acceleration)
# (cylinders ⟂ displacement | weight, model year, horsepower, mpg, origin)
# (cylinders ⟂ displacement, origin | weight, model year, horsepower, mpg, acceleration)
# (cylinders ⟂ displacement | weight, model year, mpg, origin, acceleration)
# (cylinders ⟂ mpg | weight, model year, displacement, horsepower, origin)
# (cylinders ⟂ origin, mpg | weight, model year, displacement, horsepower, acceleration)
# (cylinders ⟂ displacement, mpg | weight, model year, horsepower, origin, acceleration)
# (cylinders ⟂ model year | weight, displacement, horsepower, mpg, origin)
# (cylinders ⟂ origin, model year | weight, displacement, horsepower, mpg, acceleration)
# (cylinders ⟂ model year | weight, displacement, mpg, origin, acceleration)
# (cylinders ⟂ displacement, model year | weight, horsepower, mpg, origin, acceleration)
# (cylinders ⟂ model year, mpg | weight, displacement, horsepower, origin, acceleration)
# (cylinders ⟂ weight | model year, displacement, horsepower, mpg, origin)
# (cylinders ⟂ origin, weight | model year, displacement, horsepower, mpg, acceleration)
# (cylinders ⟂ weight | model year, displacement, mpg, origin, acceleration)
# (cylinders ⟂ displacement, weight | model year, horsepower, mpg, origin, acceleration)
# (cylinders ⟂ weight, mpg | model year, displacement, horsepower, origin, acceleration)
# (cylinders ⟂ weight, model year | displacement, horsepower, mpg, origin, acceleration)
# (cylinders ⟂ origin | weight, model year, displacement, horsepower, mpg, acceleration)
# (cylinders ⟂ displacement | weight, model year, horsepower, mpg, origin, acceleration)
# (cylinders ⟂ mpg | weight, model year, displacement, horsepower, origin, acceleration)
# (cylinders ⟂ model year | weight, displacement, horsepower, mpg, origin, acceleration)
# (cylinders ⟂ weight | model year, displacement, horsepower, mpg, origin, acceleration)
# (mpg ⟂ origin, model year | displacement)
# (mpg ⟂ cylinders, acceleration | horsepower)
# (mpg ⟂ acceleration | cylinders)
# (mpg ⟂ origin, model year | displacement, weight)
# (mpg ⟂ cylinders, acceleration | weight, horsepower)
# (mpg ⟂ acceleration | weight, cylinders)
# (mpg ⟂ origin | displacement, model year)
# (mpg ⟂ cylinders, acceleration | horsepower, model year)
# (mpg ⟂ acceleration | cylinders, model year)
# (mpg ⟂ origin, cylinders, model year, acceleration | displacement, horsepower)
# (mpg ⟂ model year | displacement, origin)
# (mpg ⟂ origin, model year, acceleration | displacement, cylinders)
# (mpg ⟂ origin, model year | displacement, acceleration)
# (mpg ⟂ cylinders, acceleration | origin, horsepower)
# (mpg ⟂ acceleration | horsepower, cylinders)
# (mpg ⟂ cylinders | horsepower, acceleration)
# (mpg ⟂ acceleration | origin, cylinders)
# (mpg ⟂ origin | displacement, weight, model year)
# (mpg ⟂ cylinders, acceleration | weight, model year, horsepower)
# (mpg ⟂ acceleration | weight, model year, cylinders)
# (mpg ⟂ origin, cylinders, model year, acceleration | displacement, weight, horsepower)
# (mpg ⟂ model year | displacement, weight, origin)
# (mpg ⟂ origin, model year, acceleration | displacement, weight, cylinders)
# (mpg ⟂ origin, model year | displacement, weight, acceleration)
# (mpg ⟂ cylinders, acceleration | origin, weight, horsepower)
# (mpg ⟂ acceleration | weight, cylinders, horsepower)
# (mpg ⟂ cylinders | weight, acceleration, horsepower)
# (mpg ⟂ acceleration | origin, weight, cylinders)
# (mpg ⟂ origin, cylinders, acceleration | displacement, horsepower, model year)
# (mpg ⟂ origin, acceleration | displacement, cylinders, model year)
# (mpg ⟂ origin | displacement, model year, acceleration)
# (mpg ⟂ cylinders, acceleration | origin, horsepower, model year)
# (mpg ⟂ acceleration | horsepower, model year, cylinders)
# (mpg ⟂ cylinders | horsepower, model year, acceleration)
# (mpg ⟂ acceleration | origin, cylinders, model year)
# (mpg ⟂ cylinders, model year, acceleration | displacement, horsepower, origin)
# (mpg ⟂ origin, model year, acceleration | displacement, horsepower, cylinders)
# (mpg ⟂ origin, cylinders, model year | displacement, horsepower, acceleration)
# (mpg ⟂ model year, acceleration | displacement, cylinders, origin)
# (mpg ⟂ model year | displacement, origin, acceleration)
# (mpg ⟂ origin, model year | displacement, cylinders, acceleration)
# (mpg ⟂ acceleration | origin, horsepower, cylinders)
# (mpg ⟂ cylinders | origin, horsepower, acceleration)
# (mpg ⟂ origin, cylinders, acceleration | displacement, weight, model year, horsepower)
# (mpg ⟂ origin, acceleration | displacement, weight, model year, cylinders)
# (mpg ⟂ origin | displacement, weight, model year, acceleration)
# (mpg ⟂ cylinders, acceleration | origin, weight, model year, horsepower)
# (mpg ⟂ acceleration | weight, model year, cylinders, horsepower)
# (mpg ⟂ cylinders | weight, model year, acceleration, horsepower)
# (mpg ⟂ acceleration | origin, weight, model year, cylinders)
# (mpg ⟂ cylinders, model year, acceleration | displacement, weight, origin, horsepower)
# (mpg ⟂ origin, model year, acceleration | displacement, weight, cylinders, horsepower)
# (mpg ⟂ origin, cylinders, model year | displacement, weight, acceleration, horsepower)
# (mpg ⟂ model year, acceleration | displacement, weight, origin, cylinders)
# (mpg ⟂ model year | displacement, weight, origin, acceleration)
# (mpg ⟂ origin, model year | displacement, weight, cylinders, acceleration)
# (mpg ⟂ acceleration | origin, weight, cylinders, horsepower)
# (mpg ⟂ cylinders | origin, weight, acceleration, horsepower)
# (mpg ⟂ cylinders, acceleration | displacement, horsepower, model year, origin)
# (mpg ⟂ origin, acceleration | displacement, horsepower, model year, cylinders)
# (mpg ⟂ origin, cylinders | displacement, horsepower, model year, acceleration)
# (mpg ⟂ acceleration | displacement, cylinders, model year, origin)
# (mpg ⟂ origin | displacement, cylinders, model year, acceleration)
# (mpg ⟂ acceleration | origin, horsepower, model year, cylinders)
# (mpg ⟂ cylinders | origin, horsepower, model year, acceleration)
# (mpg ⟂ model year, acceleration | displacement, horsepower, origin, cylinders)
# (mpg ⟂ cylinders, model year | displacement, horsepower, origin, acceleration)
# (mpg ⟂ origin, model year | displacement, horsepower, cylinders, acceleration)
# (mpg ⟂ model year | displacement, cylinders, origin, acceleration)
# (mpg ⟂ cylinders, acceleration | weight, model year, displacement, horsepower, origin)
# (mpg ⟂ origin, acceleration | weight, model year, displacement, cylinders, horsepower)
# (mpg ⟂ origin, cylinders | weight, model year, displacement, horsepower, acceleration)
# (mpg ⟂ acceleration | weight, model year, displacement, cylinders, origin)
# (mpg ⟂ origin | weight, model year, displacement, cylinders, acceleration)
# (mpg ⟂ acceleration | weight, model year, cylinders, horsepower, origin)
# (mpg ⟂ cylinders | weight, model year, horsepower, origin, acceleration)
# (mpg ⟂ model year, acceleration | weight, displacement, cylinders, horsepower, origin)
# (mpg ⟂ cylinders, model year | weight, displacement, horsepower, origin, acceleration)
# (mpg ⟂ origin, model year | weight, displacement, cylinders, horsepower, acceleration)
# (mpg ⟂ model year | weight, displacement, cylinders, origin, acceleration)
# (mpg ⟂ acceleration | model year, displacement, horsepower, cylinders, origin)
# (mpg ⟂ cylinders | model year, displacement, horsepower, origin, acceleration)
# (mpg ⟂ origin | model year, displacement, horsepower, cylinders, acceleration)
# (mpg ⟂ model year | displacement, horsepower, cylinders, origin, acceleration)
# (mpg ⟂ acceleration | weight, model year, displacement, horsepower, cylinders, origin)
# (mpg ⟂ cylinders | weight, model year, displacement, horsepower, origin, acceleration)
# (mpg ⟂ origin | weight, model year, displacement, cylinders, horsepower, acceleration)
# (mpg ⟂ model year | weight, displacement, cylinders, horsepower, origin, acceleration)
# (origin ⟂ cylinders, acceleration, horsepower | mpg)
# (origin ⟂ weight, model year, horsepower, mpg, cylinders, acceleration | displacement)
# (origin ⟂ cylinders, acceleration | horsepower)
# (origin ⟂ acceleration | cylinders)
# (origin ⟂ horsepower, cylinders, acceleration | weight, mpg)
# (origin ⟂ model year, mpg, horsepower, cylinders, acceleration | displacement, weight)
# (origin ⟂ cylinders, acceleration | weight, horsepower)
# (origin ⟂ acceleration | weight, cylinders)
# (origin ⟂ cylinders, acceleration, horsepower | model year, mpg)
# (origin ⟂ weight, horsepower, mpg, cylinders, acceleration | displacement, model year)
# (origin ⟂ cylinders, acceleration | horsepower, model year)
# (origin ⟂ acceleration | cylinders, model year)
# (origin ⟂ weight, model year, horsepower, cylinders, acceleration | displacement, mpg)
# (origin ⟂ cylinders, acceleration | horsepower, mpg)
# (origin ⟂ horsepower, acceleration | cylinders, mpg)
# (origin ⟂ cylinders, horsepower | acceleration, mpg)
# (origin ⟂ weight, model year, mpg, cylinders, acceleration | displacement, horsepower)
# (origin ⟂ weight, model year, mpg, horsepower, acceleration | displacement, cylinders)
# (origin ⟂ weight, model year, horsepower, mpg, cylinders | displacement, acceleration)
# (origin ⟂ acceleration | horsepower, cylinders)
# (origin ⟂ cylinders | horsepower, acceleration)
# (origin ⟂ horsepower, cylinders, acceleration | weight, model year, mpg)
# (origin ⟂ horsepower, cylinders, acceleration, mpg | displacement, weight, model year)
# (origin ⟂ cylinders, acceleration | weight, model year, horsepower)
# (origin ⟂ acceleration | weight, model year, cylinders)
# (origin ⟂ horsepower, model year, cylinders, acceleration | displacement, weight, mpg)
# (origin ⟂ cylinders, acceleration | weight, horsepower, mpg)
# (origin ⟂ horsepower, acceleration | weight, cylinders, mpg)
# (origin ⟂ horsepower, cylinders | weight, acceleration, mpg)
# (origin ⟂ cylinders, model year, acceleration, mpg | displacement, weight, horsepower)
# (origin ⟂ horsepower, model year, acceleration, mpg | displacement, weight, cylinders)
# (origin ⟂ horsepower, model year, cylinders, mpg | displacement, weight, acceleration)
# (origin ⟂ acceleration | weight, cylinders, horsepower)
# (origin ⟂ cylinders | weight, acceleration, horsepower)
# (origin ⟂ weight, cylinders, horsepower, acceleration | displacement, model year, mpg)
# (origin ⟂ cylinders, acceleration | horsepower, model year, mpg)
# (origin ⟂ horsepower, acceleration | cylinders, model year, mpg)
# (origin ⟂ cylinders, horsepower | model year, acceleration, mpg)
# (origin ⟂ weight, cylinders, acceleration, mpg | displacement, horsepower, model year)
# (origin ⟂ weight, horsepower, acceleration, mpg | displacement, cylinders, model year)
# (origin ⟂ weight, cylinders, horsepower, mpg | displacement, model year, acceleration)
# (origin ⟂ acceleration | horsepower, model year, cylinders)
# (origin ⟂ cylinders | horsepower, model year, acceleration)
# (origin ⟂ weight, model year, cylinders, acceleration | displacement, horsepower, mpg)
# (origin ⟂ weight, model year, horsepower, acceleration | displacement, cylinders, mpg)
# (origin ⟂ weight, model year, cylinders, horsepower | displacement, acceleration, mpg)
# (origin ⟂ acceleration | horsepower, cylinders, mpg)
# (origin ⟂ cylinders | horsepower, acceleration, mpg)
# (origin ⟂ horsepower | cylinders, acceleration, mpg)
# (origin ⟂ weight, model year, acceleration, mpg | displacement, horsepower, cylinders)
# (origin ⟂ weight, model year, cylinders, mpg | displacement, horsepower, acceleration)
# (origin ⟂ weight, model year, horsepower, mpg | displacement, cylinders, acceleration)
# (origin ⟂ horsepower, cylinders, acceleration | displacement, weight, model year, mpg)
# (origin ⟂ cylinders, acceleration | weight, model year, horsepower, mpg)
# (origin ⟂ horsepower, acceleration | weight, model year, cylinders, mpg)
# (origin ⟂ horsepower, cylinders | weight, model year, acceleration, mpg)
# (origin ⟂ cylinders, acceleration, mpg | displacement, weight, model year, horsepower)
# (origin ⟂ horsepower, acceleration, mpg | displacement, weight, model year, cylinders)
# (origin ⟂ horsepower, cylinders, mpg | displacement, weight, model year, acceleration)
# (origin ⟂ acceleration | weight, model year, cylinders, horsepower)
# (origin ⟂ cylinders | weight, model year, acceleration, horsepower)
# (origin ⟂ cylinders, model year, acceleration | displacement, weight, horsepower, mpg)
# (origin ⟂ horsepower, model year, acceleration | displacement, weight, cylinders, mpg)
# (origin ⟂ horsepower, model year, cylinders | displacement, weight, acceleration, mpg)
# (origin ⟂ acceleration | weight, cylinders, horsepower, mpg)
# (origin ⟂ cylinders | weight, acceleration, horsepower, mpg)
# (origin ⟂ horsepower | weight, cylinders, acceleration, mpg)
# (origin ⟂ model year, acceleration, mpg | displacement, weight, cylinders, horsepower)
# (origin ⟂ cylinders, model year, mpg | displacement, weight, acceleration, horsepower)
# (origin ⟂ horsepower, model year, mpg | displacement, weight, cylinders, acceleration)
# (origin ⟂ weight, cylinders, acceleration | displacement, horsepower, model year, mpg)
# (origin ⟂ weight, horsepower, acceleration | displacement, cylinders, model year, mpg)
# (origin ⟂ weight, cylinders, horsepower | displacement, model year, acceleration, mpg)
# (origin ⟂ acceleration | horsepower, model year, cylinders, mpg)
# (origin ⟂ cylinders | horsepower, model year, acceleration, mpg)
# (origin ⟂ horsepower | cylinders, model year, acceleration, mpg)
# (origin ⟂ weight, acceleration, mpg | displacement, horsepower, model year, cylinders)
# (origin ⟂ weight, cylinders, mpg | displacement, horsepower, model year, acceleration)
# (origin ⟂ weight, horsepower, mpg | displacement, cylinders, model year, acceleration)
# (origin ⟂ weight, model year, acceleration | displacement, horsepower, cylinders, mpg)
# (origin ⟂ weight, model year, cylinders | displacement, horsepower, acceleration, mpg)
# (origin ⟂ weight, model year, horsepower | displacement, cylinders, acceleration, mpg)
# (origin ⟂ weight, model year, mpg | displacement, horsepower, cylinders, acceleration)
# (origin ⟂ cylinders, acceleration | weight, model year, displacement, horsepower, mpg)
# (origin ⟂ horsepower, acceleration | weight, model year, displacement, cylinders, mpg)
# (origin ⟂ horsepower, cylinders | weight, model year, displacement, mpg, acceleration)
# (origin ⟂ acceleration | weight, model year, cylinders, horsepower, mpg)
# (origin ⟂ cylinders | weight, model year, horsepower, mpg, acceleration)
# (origin ⟂ horsepower | weight, model year, cylinders, mpg, acceleration)
# (origin ⟂ acceleration, mpg | weight, model year, displacement, cylinders, horsepower)
# (origin ⟂ cylinders, mpg | weight, model year, displacement, horsepower, acceleration)
# (origin ⟂ horsepower, mpg | weight, model year, displacement, cylinders, acceleration)
# (origin ⟂ model year, acceleration | weight, displacement, cylinders, horsepower, mpg)
# (origin ⟂ cylinders, model year | weight, displacement, horsepower, mpg, acceleration)
# (origin ⟂ horsepower, model year | weight, displacement, cylinders, mpg, acceleration)
# (origin ⟂ model year, mpg | weight, displacement, cylinders, horsepower, acceleration)
# (origin ⟂ weight, acceleration | model year, displacement, horsepower, cylinders, mpg)
# (origin ⟂ weight, cylinders | model year, displacement, horsepower, mpg, acceleration)
# (origin ⟂ weight, horsepower | model year, displacement, cylinders, mpg, acceleration)
# (origin ⟂ weight, mpg | model year, displacement, horsepower, cylinders, acceleration)
# (origin ⟂ weight, model year | displacement, horsepower, cylinders, mpg, acceleration)
# (origin ⟂ acceleration | weight, model year, displacement, horsepower, cylinders, mpg)
# (origin ⟂ cylinders | weight, model year, displacement, horsepower, mpg, acceleration)
# (origin ⟂ horsepower | weight, model year, displacement, cylinders, mpg, acceleration)
# (origin ⟂ mpg | weight, model year, displacement, cylinders, horsepower, acceleration)
# (origin ⟂ model year | weight, displacement, cylinders, horsepower, mpg, acceleration)
# (origin ⟂ weight | model year, displacement, horsepower, cylinders, mpg, acceleration)
# (acceleration ⟂ displacement, weight, model year, origin | mpg)
# (acceleration ⟂ origin, model year | displacement)
# (acceleration ⟂ weight, model year, mpg, displacement, origin | horsepower)
# (acceleration ⟂ weight, model year, mpg, displacement, horsepower, origin | cylinders)
# (acceleration ⟂ displacement, model year, origin | weight, mpg)
# (acceleration ⟂ origin, model year | displacement, weight)
# (acceleration ⟂ displacement, model year, origin, mpg | weight, horsepower)
# (acceleration ⟂ model year, mpg, displacement, horsepower, origin | weight, cylinders)
# (acceleration ⟂ displacement, weight, origin | model year, mpg)
# (acceleration ⟂ origin | displacement, model year)
# (acceleration ⟂ displacement, weight, origin, mpg | horsepower, model year)
# (acceleration ⟂ weight, mpg, displacement, horsepower, origin | cylinders, model year)
# (acceleration ⟂ origin, weight, model year | displacement, mpg)
# (acceleration ⟂ displacement, weight, model year, origin | horsepower, mpg)
# (acceleration ⟂ displacement, weight, model year | origin, mpg)
# (acceleration ⟂ weight, model year, displacement, horsepower, origin | cylinders, mpg)
# (acceleration ⟂ origin, weight, model year, mpg | displacement, horsepower)
# (acceleration ⟂ model year | displacement, origin)
# (acceleration ⟂ weight, model year, mpg, origin, horsepower | displacement, cylinders)
# (acceleration ⟂ displacement, weight, model year, mpg | origin, horsepower)
# (acceleration ⟂ weight, model year, mpg, displacement, origin | horsepower, cylinders)
# (acceleration ⟂ weight, model year, mpg, displacement, horsepower | origin, cylinders)
# (acceleration ⟂ displacement, origin | weight, model year, mpg)
# (acceleration ⟂ origin | displacement, weight, model year)
# (acceleration ⟂ displacement, origin, mpg | weight, model year, horsepower)
# (acceleration ⟂ displacement, horsepower, origin, mpg | weight, model year, cylinders)
# (acceleration ⟂ origin, model year | displacement, weight, mpg)
# (acceleration ⟂ displacement, model year, origin | weight, horsepower, mpg)
# (acceleration ⟂ displacement, model year | origin, weight, mpg)
# (acceleration ⟂ displacement, horsepower, model year, origin | weight, cylinders, mpg)
# (acceleration ⟂ origin, model year, mpg | displacement, weight, horsepower)
# (acceleration ⟂ model year | displacement, weight, origin)
# (acceleration ⟂ origin, horsepower, model year, mpg | displacement, weight, cylinders)
# (acceleration ⟂ displacement, model year, mpg | origin, weight, horsepower)
# (acceleration ⟂ displacement, model year, origin, mpg | weight, cylinders, horsepower)
# (acceleration ⟂ displacement, horsepower, model year, mpg | origin, weight, cylinders)
# (acceleration ⟂ origin, weight | displacement, model year, mpg)
# (acceleration ⟂ displacement, weight, origin | horsepower, model year, mpg)
# (acceleration ⟂ displacement, weight | origin, model year, mpg)
# (acceleration ⟂ displacement, weight, origin, horsepower | cylinders, model year, mpg)
# (acceleration ⟂ origin, weight, mpg | displacement, horsepower, model year)
# (acceleration ⟂ origin, weight, horsepower, mpg | displacement, cylinders, model year)
# (acceleration ⟂ displacement, weight, mpg | origin, horsepower, model year)
# (acceleration ⟂ displacement, weight, origin, mpg | horsepower, model year, cylinders)
# (acceleration ⟂ displacement, weight, horsepower, mpg | origin, cylinders, model year)
# (acceleration ⟂ origin, weight, model year | displacement, horsepower, mpg)
# (acceleration ⟂ weight, model year | displacement, origin, mpg)
# (acceleration ⟂ origin, weight, model year, horsepower | displacement, cylinders, mpg)
# (acceleration ⟂ displacement, weight, model year | origin, horsepower, mpg)
# (acceleration ⟂ displacement, weight, model year, origin | horsepower, cylinders, mpg)
# (acceleration ⟂ displacement, weight, model year, horsepower | origin, cylinders, mpg)
# (acceleration ⟂ weight, model year, mpg | displacement, horsepower, origin)
# (acceleration ⟂ origin, weight, model year, mpg | displacement, horsepower, cylinders)
# (acceleration ⟂ weight, model year, horsepower, mpg | displacement, cylinders, origin)
# (acceleration ⟂ displacement, weight, model year, mpg | origin, horsepower, cylinders)
# (acceleration ⟂ origin | displacement, weight, model year, mpg)
# (acceleration ⟂ displacement, origin | weight, model year, horsepower, mpg)
# (acceleration ⟂ displacement | origin, weight, model year, mpg)
# (acceleration ⟂ displacement, horsepower, origin | weight, model year, cylinders, mpg)
# (acceleration ⟂ origin, mpg | displacement, weight, model year, horsepower)
# (acceleration ⟂ origin, horsepower, mpg | displacement, weight, model year, cylinders)
# (acceleration ⟂ displacement, mpg | origin, weight, model year, horsepower)
# (acceleration ⟂ displacement, origin, mpg | weight, model year, cylinders, horsepower)
# (acceleration ⟂ displacement, horsepower, mpg | origin, weight, model year, cylinders)
# (acceleration ⟂ origin, model year | displacement, weight, horsepower, mpg)
# (acceleration ⟂ model year | displacement, weight, origin, mpg)
# (acceleration ⟂ origin, horsepower, model year | displacement, weight, cylinders, mpg)
# (acceleration ⟂ displacement, model year | origin, weight, horsepower, mpg)
# (acceleration ⟂ displacement, model year, origin | weight, cylinders, horsepower, mpg)
# (acceleration ⟂ displacement, horsepower, model year | origin, weight, cylinders, mpg)
# (acceleration ⟂ model year, mpg | displacement, weight, origin, horsepower)
# (acceleration ⟂ origin, model year, mpg | displacement, weight, cylinders, horsepower)
# (acceleration ⟂ horsepower, model year, mpg | displacement, weight, origin, cylinders)
# (acceleration ⟂ displacement, model year, mpg | origin, weight, cylinders, horsepower)
# (acceleration ⟂ origin, weight | displacement, horsepower, model year, mpg)
# (acceleration ⟂ weight | displacement, model year, origin, mpg)
# (acceleration ⟂ origin, weight, horsepower | displacement, cylinders, model year, mpg)
# (acceleration ⟂ displacement, weight | origin, horsepower, model year, mpg)
# (acceleration ⟂ displacement, weight, origin | horsepower, model year, cylinders, mpg)
# (acceleration ⟂ displacement, weight, horsepower | origin, cylinders, model year, mpg)
# (acceleration ⟂ weight, mpg | displacement, horsepower, model year, origin)
# (acceleration ⟂ origin, weight, mpg | displacement, horsepower, model year, cylinders)
# (acceleration ⟂ weight, horsepower, mpg | displacement, cylinders, model year, origin)
# (acceleration ⟂ displacement, weight, mpg | origin, horsepower, model year, cylinders)
# (acceleration ⟂ weight, model year | displacement, horsepower, origin, mpg)
# (acceleration ⟂ origin, weight, model year | displacement, horsepower, cylinders, mpg)
# (acceleration ⟂ weight, model year, horsepower | displacement, cylinders, origin, mpg)
# (acceleration ⟂ displacement, weight, model year | origin, horsepower, cylinders, mpg)
# (acceleration ⟂ weight, model year, mpg | displacement, horsepower, origin, cylinders)
# (acceleration ⟂ origin | weight, model year, displacement, horsepower, mpg)
# (acceleration ⟂ origin, horsepower | weight, model year, displacement, cylinders, mpg)
# (acceleration ⟂ displacement | weight, model year, horsepower, mpg, origin)
# (acceleration ⟂ displacement, origin | weight, model year, cylinders, horsepower, mpg)
# (acceleration ⟂ displacement, horsepower | weight, model year, cylinders, mpg, origin)
# (acceleration ⟂ mpg | weight, model year, displacement, horsepower, origin)
# (acceleration ⟂ origin, mpg | weight, model year, displacement, cylinders, horsepower)
# (acceleration ⟂ horsepower, mpg | weight, model year, displacement, cylinders, origin)
# (acceleration ⟂ displacement, mpg | weight, model year, cylinders, horsepower, origin)
# (acceleration ⟂ model year | weight, displacement, horsepower, mpg, origin)
# (acceleration ⟂ origin, model year | weight, displacement, cylinders, horsepower, mpg)
# (acceleration ⟂ horsepower, model year | weight, displacement, cylinders, mpg, origin)
# (acceleration ⟂ displacement, model year | weight, cylinders, horsepower, mpg, origin)
# (acceleration ⟂ model year, mpg | weight, displacement, cylinders, horsepower, origin)
# (acceleration ⟂ weight | model year, displacement, horsepower, mpg, origin)
# (acceleration ⟂ origin, weight | model year, displacement, horsepower, cylinders, mpg)
# (acceleration ⟂ weight, horsepower | model year, displacement, cylinders, mpg, origin)
# (acceleration ⟂ displacement, weight | model year, horsepower, cylinders, mpg, origin)
# (acceleration ⟂ weight, mpg | model year, displacement, horsepower, cylinders, origin)
# (acceleration ⟂ weight, model year | displacement, horsepower, cylinders, mpg, origin)
# (acceleration ⟂ origin | weight, model year, displacement, horsepower, cylinders, mpg)
# (acceleration ⟂ horsepower | weight, model year, displacement, cylinders, mpg, origin)
# (acceleration ⟂ displacement | weight, model year, horsepower, cylinders, mpg, origin)
# (acceleration ⟂ mpg | weight, model year, displacement, horsepower, cylinders, origin)
# (acceleration ⟂ model year | weight, displacement, horsepower, cylinders, mpg, origin)
# (acceleration ⟂ weight | model year, displacement, horsepower, cylinders, mpg, origin)
